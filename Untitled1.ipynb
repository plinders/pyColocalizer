# %%
from colocalizer_functions import *
from coloc_pipeline import *
import pandas as pd
import numpy as np
from os.path import basename, splitext
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
images = loadImage('data/test1.tif')
neg = loadImage('data/dapi_cd9.tif')

# %%
df, img_shape = contourImage(images, 1, 2)
df_neg, img_shape_neg = contourImage(neg, 1, 3)

# %%
df
# Out:
#        contour_chan1  contour_chan2  orig_chan1  orig_chan2
# 0                NaN            NaN         0.0         0.0
# 1                NaN            NaN         0.0         0.0
# 2                NaN            NaN         0.0         0.0
# 3                NaN            NaN         0.0         0.0
# 4                NaN            NaN         0.0         0.0
# 5                NaN            NaN         0.0         0.0
# 6                NaN            NaN         0.0         0.0
# 7                NaN            NaN         0.0         0.0
# 8                NaN            NaN         0.0         0.0
# 9                NaN            NaN         0.0         0.0
# 10               NaN            NaN         0.0         0.0
# 11               NaN            NaN         0.0         0.0
# 12               NaN            NaN         0.0         0.0
# 13               NaN            NaN         0.0         0.0
# 14               NaN            NaN         0.0         0.0
# ...

# %%
df_neg = applyThreshold(df_neg, 0)

# %%
MandersCoef(df_neg)
# Out:
# (0.84279280979293658, 1.0, 0.84279280979293658, 1.0)

# %%
df_neg
# Out:
#        contour_chan1  contour_chan2  orig_chan1  orig_chan2  thres_chan1  \
# 0                NaN            NaN         0.0         0.0          NaN
# 1                NaN            NaN         0.0         0.0          NaN
# 2                NaN            NaN         0.0         0.0          NaN
# 3                NaN            NaN         0.0         0.0          NaN
# 4                NaN            NaN         0.0         0.0          NaN
# 5                NaN            NaN         0.0         0.0          NaN
# 6                NaN            NaN         0.0         0.0          NaN
# 7                NaN            NaN         0.0         0.0          NaN
# 8                NaN            NaN         0.0         0.0          NaN
# 9                NaN            NaN         0.0         0.0          NaN
# 10               NaN            NaN         0.0         0.0          NaN
# 11               NaN            NaN         0.0         0.0          NaN
# ...

# %%
plt.hexbin(df_neg["thres_chan1"].dropna(), df_neg["thres_chan2"].dropna())
